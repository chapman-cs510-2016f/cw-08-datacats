# %% [markdown]
# # CW 08
# ### Simrath Ratra & Andrew Nguyen

# %%
import cplaneJulia 
## without numba optimization
c = cplaneJulia.JuliaPlane(-2,2,3000,-2,2,3000) 
# %time c.set_f()
c.show()
# Out:
# CPU times: user 30.6 s, sys: 996 ms, total: 31.6 s
# Wall time: 32 s
# /usr/lib/python3/dist-packages/matplotlib/collections.py:571: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
import cplaneJulia 
c = cplaneJulia.JuliaPlane(-2,2,4000,-2,2,4000) 
# %time c.set_f()
c.show()
# Out:
# CPU times: user 1.31 s, sys: 1.73 s, total: 3.04 s
# Wall time: 9.19 s
# /usr/lib/python3/dist-packages/matplotlib/collections.py:571: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
c = cplaneJulia.JuliaPlane(-2,2,3000,-2,2,3000) 
# %time c.set_f()
c.show()
# Out:
# CPU times: user 692 ms, sys: 836 ms, total: 1.53 s
# Wall time: 2.52 s
# /usr/lib/python3/dist-packages/matplotlib/collections.py:571: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %% [markdown]
# ### Conclusion
#
# From our findings, our first function implementation of the julia plane, with paramters x = -2,2, y=-2,2, with 6000 points inbetween, the process took around 32 seconds to run.
# With our numba optimization, the process took only 2.52 seconds to run.
# It is clear that the numba optimization significantly reduces the run time in the creation of our Julia plane, and makes creation of large data or spaces run a lot more efficiently and faster.
